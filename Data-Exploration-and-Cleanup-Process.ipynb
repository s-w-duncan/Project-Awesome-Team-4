# %% [markdown]
# # Data Exploration and Cleanup Process

# %%
# Import Dependancies
import pandas as pd
from config import key
import numpy as np
import requests
import time
from scipy.stats import linregress
from matplotlib import pyplot as plt
import json

# %% [markdown]
# #### Compiling Chicago Cubs Attendance Data from 2015 - 2019.

# %%
# Load Attendance and Game Data
cubs_2015_2019 = "Resources/2015_2019CubsAttendanceBreakdownX.xls"

# Read Attendance and Game Data
cubs_df = pd.read_excel(cubs_2015_2019)
cubs_df["Season Win %"] = cubs_df["Season Win %"].astype(float).map("{:,.3f}".format)

# %%
cubs_df
# Out:
#            Date      Month        Day  Season  Gm#   Tm  Opp Win/Loss  \
# 0    2015-04-05      April     Sunday    2015    1  CHC  STL        L
# 1    2015-04-08      April  Wednesday    2015    2  CHC  STL        W
# 2    2015-04-13      April     Monday    2015    6  CHC  CIN        W
# 3    2015-04-14      April    Tuesday    2015    7  CHC  CIN        L
# 4    2015-04-15      April  Wednesday    2015    8  CHC  CIN        W
# ..          ...        ...        ...     ...  ...  ...  ...      ...
# 400  2019-09-18  September  Wednesday    2019  152  CHC  CIN        L
# 401  2019-09-19  September   Thursday    2019  153  CHC  STL        L
# 402  2019-09-20  September     Friday    2019  154  CHC  STL        L
# 403  2019-09-21  September   Saturday    2019  155  CHC  STL        L
# 404  2019-09-22  September     Sunday    2019  156  CHC  STL        L
#
#      Season Wins  Season Losses Season Win % Day/ Night Game  Attendance
# ...

# %%
cubs_df.dtypes
# Out:
# Date                object
# Month               object
# Day                 object
# Season               int64
# Gm#                  int64
# Tm                  object
# Opp                 object
# Wins / Losses       object
# Wins                 int64
# Losses               int64
# Win %              float64
# Day/ Night Game     object
# Attendance           int64
# dtype: object

# %%
# Request Weather Info
url = "http://api.worldweatheronline.com/premium/v1/past-weather.ashx?key="
end_url0 = "&q=60613&format=json&date=2015-04-01&enddate=2015-04-30&tp=24"
response0 = requests.get(url + key + end_url0).json()

# %%
end_url1 = "&q=60613&format=json&date=2015-05-01&enddate=2015-05-31&tp=24"
response1 = requests.get(url + key + end_url1).json()

# %%
end_url2 = "&q=60613&format=json&date=2015-06-01&enddate=2015-06-30&tp=24"
response2 = requests.get(url + key + end_url2).json()

# %%
end_url3 = "&q=60613&format=json&date=2015-07-01&enddate=2015-07-31&tp=24"
response3 = requests.get(url + key + end_url3).json()

# %%
end_url4 = "&q=60613&format=json&date=2015-08-01&enddate=2015-08-31&tp=24"
response4 = requests.get(url + key + end_url4).json()

# %%
end_url5 = "&q=60613&format=json&date=2015-09-01&enddate=2015-09-30&tp=24"
response5 = requests.get(url + key + end_url5).json()

# %%
end_url6 = "&q=60613&format=json&date=2016-04-01&enddate=2016-04-30&tp=24"
response6 = requests.get(url + key + end_url6).json()

# %%
end_url7 = "&q=60613&format=json&date=2016-05-01&enddate=2016-05-31&tp=24"
response7 = requests.get(url + key + end_url7).json()

# %%
end_url8 = "&q=60613&format=json&date=2016-06-01&enddate=2016-06-30&tp=24"
response8 = requests.get(url + key + end_url8).json()

# %%
end_url9 = "&q=60613&format=json&date=2016-07-01&enddate=2016-07-31&tp=24"
response9 = requests.get(url + key + end_url9).json()

# %%
end_url10 = "&q=60613&format=json&date=2016-08-01&enddate=2016-08-31&tp=24"
response10 = requests.get(url + key + end_url10).json()

# %%
end_url11 = "&q=60613&format=json&date=2016-09-01&enddate=2016-09-30&tp=24"
response11 = requests.get(url + key + end_url11).json()

# %%
end_url12 = "&q=60613&format=json&date=2017-04-01&enddate=2017-04-30&tp=24"
response12 = requests.get(url + key + end_url12).json()

# %%
end_url13 = "&q=60613&format=json&date=2017-05-01&enddate=2017-05-31&tp=24"
response13 = requests.get(url + key + end_url13).json()

# %%
end_url14 = "&q=60613&format=json&date=2017-06-01&enddate=2017-06-30&tp=24"
response14 = requests.get(url + key + end_url14).json()

# %%
end_url15 = "&q=60613&format=json&date=2017-07-01&enddate=2017-07-31&tp=24"
response15 = requests.get(url + key + end_url15).json()

# %%
end_url16 = "&q=60613&format=json&date=2017-08-01&enddate=2017-08-31&tp=24"
response16 = requests.get(url + key + end_url16).json()

# %%
end_url17 = "&q=60613&format=json&date=2017-09-01&enddate=2017-10-02&tp=24"
response17 = requests.get(url + key + end_url17).json()

# %%
end_url18 = "&q=60613&format=json&date=2018-04-01&enddate=2018-04-30&tp=24"
response18 = requests.get(url + key + end_url18).json()

# %%
end_url19 = "&q=60613&format=json&date=2018-05-01&enddate=2018-05-31&tp=24"
response19 = requests.get(url + key + end_url19).json()

# %%
end_url20 = "&q=60613&format=json&date=2018-06-01&enddate=2018-06-30&tp=24"
response20 = requests.get(url + key + end_url20).json()

# %%
end_url21 = "&q=60613&format=json&date=2018-07-01&enddate=2018-07-31&tp=24"
response21 = requests.get(url + key + end_url21).json()

# %%
end_url22 = "&q=60613&format=json&date=2018-08-01&enddate=2018-08-31&tp=24"
response22 = requests.get(url + key + end_url22).json()

# %%
end_url23 = "&q=60613&format=json&date=2018-09-01&enddate=2018-09-30&tp=24"
response23 = requests.get(url + key + end_url23).json()

# %%
end_url24 = "&q=60613&format=json&date=2019-04-01&enddate=2019-04-30&tp=24"
response24 = requests.get(url + key + end_url24).json()

# %%
end_url25 = "&q=60613&format=json&date=2019-05-01&enddate=2019-05-31&tp=24"
response25 = requests.get(url + key + end_url25).json()

# %%
end_url26 = "&q=60613&format=json&date=2019-06-01&enddate=2019-06-30&tp=24"
response26 = requests.get(url + key + end_url26).json()

# %%
end_url27 = "&q=60613&format=json&date=2019-07-01&enddate=2019-07-31&tp=24"
response27 = requests.get(url + key + end_url27).json()

# %%
end_url28 = "&q=60613&format=json&date=2019-08-01&enddate=2019-08-31&tp=24"
response28 = requests.get(url + key + end_url28).json()

# %%
end_url29 = "&q=60613&format=json&date=2019-09-01&enddate=2019-09-30&tp=24"
response29 = requests.get(url + key + end_url29).json()

# %%
# Define Lists
date = []
temp = []
snow = []
feels = []
chill = []
hum = []
cloud = []
wind = []
precip = []

# %%
# Append Weather Data Into Lists
for x in response0["data"]["weather"]:  
    
    try:
        date.append(x['date'])
        temp.append(x['maxtempF'])
        snow.append(x['totalSnow_cm'])
        feels.append(x['hourly'][0]['FeelsLikeF'])
        chill.append(x['hourly'][0]['WindChillF'])
        hum.append(x['hourly'][0]['humidity'])
        cloud.append(x['hourly'][0]['cloudcover'])
        wind.append(x['hourly'][0]['WindGustMiles'])
        precip.append(x['hourly'][0]['precipInches'])
              
    except KeyError:
        print("Error")

# %%
for x in response1["data"]["weather"]:  
    
    try:
        date.append(x['date'])
        temp.append(x['maxtempF'])
        snow.append(x['totalSnow_cm'])
        feels.append(x['hourly'][0]['FeelsLikeF'])
        chill.append(x['hourly'][0]['WindChillF'])
        hum.append(x['hourly'][0]['humidity'])
        cloud.append(x['hourly'][0]['cloudcover'])
        wind.append(x['hourly'][0]['WindGustMiles'])
        precip.append(x['hourly'][0]['precipInches'])
              
    except KeyError:
        print("Error")

# %%
for x in response2["data"]["weather"]:  
    
    try:
        date.append(x['date'])
        temp.append(x['maxtempF'])
        snow.append(x['totalSnow_cm'])
        feels.append(x['hourly'][0]['FeelsLikeF'])
        chill.append(x['hourly'][0]['WindChillF'])
        hum.append(x['hourly'][0]['humidity'])
        cloud.append(x['hourly'][0]['cloudcover'])
        wind.append(x['hourly'][0]['WindGustMiles'])
        precip.append(x['hourly'][0]['precipInches'])
              
    except KeyError:
        print("Error")

# %%
for x in response3["data"]["weather"]:  
    
    try:
        date.append(x['date'])
        temp.append(x['maxtempF'])
        snow.append(x['totalSnow_cm'])
        feels.append(x['hourly'][0]['FeelsLikeF'])
        chill.append(x['hourly'][0]['WindChillF'])
        hum.append(x['hourly'][0]['humidity'])
        cloud.append(x['hourly'][0]['cloudcover'])
        wind.append(x['hourly'][0]['WindGustMiles'])
        precip.append(x['hourly'][0]['precipInches'])
              
    except KeyError:
        print("Error")

# %%
for x in response4["data"]["weather"]:  
    
    try:
        date.append(x['date'])
        temp.append(x['maxtempF'])
        snow.append(x['totalSnow_cm'])
        feels.append(x['hourly'][0]['FeelsLikeF'])
        chill.append(x['hourly'][0]['WindChillF'])
        hum.append(x['hourly'][0]['humidity'])
        cloud.append(x['hourly'][0]['cloudcover'])
        wind.append(x['hourly'][0]['WindGustMiles'])
        precip.append(x['hourly'][0]['precipInches'])
              
    except KeyError:
        print("Error")

# %%
for x in response5["data"]["weather"]:  
    
    try:
        date.append(x['date'])
        temp.append(x['maxtempF'])
        snow.append(x['totalSnow_cm'])
        feels.append(x['hourly'][0]['FeelsLikeF'])
        chill.append(x['hourly'][0]['WindChillF'])
        hum.append(x['hourly'][0]['humidity'])
        cloud.append(x['hourly'][0]['cloudcover'])
        wind.append(x['hourly'][0]['WindGustMiles'])
        precip.append(x['hourly'][0]['precipInches'])
              
    except KeyError:
        print("Error")

# %%
for x in response6["data"]["weather"]:  
    
    try:
        date.append(x['date'])
        temp.append(x['maxtempF'])
        snow.append(x['totalSnow_cm'])
        feels.append(x['hourly'][0]['FeelsLikeF'])
        chill.append(x['hourly'][0]['WindChillF'])
        hum.append(x['hourly'][0]['humidity'])
        cloud.append(x['hourly'][0]['cloudcover'])
        wind.append(x['hourly'][0]['WindGustMiles'])
        precip.append(x['hourly'][0]['precipInches'])
              
    except KeyError:
        print("Error")

# %%
for x in response7["data"]["weather"]:  
    
    try:
        date.append(x['date'])
        temp.append(x['maxtempF'])
        snow.append(x['totalSnow_cm'])
        feels.append(x['hourly'][0]['FeelsLikeF'])
        chill.append(x['hourly'][0]['WindChillF'])
        hum.append(x['hourly'][0]['humidity'])
        cloud.append(x['hourly'][0]['cloudcover'])
        wind.append(x['hourly'][0]['WindGustMiles'])
        precip.append(x['hourly'][0]['precipInches'])
              
    except KeyError:
        print("Error")

# %%
for x in response8["data"]["weather"]:  
    
    try:
        date.append(x['date'])
        temp.append(x['maxtempF'])
        snow.append(x['totalSnow_cm'])
        feels.append(x['hourly'][0]['FeelsLikeF'])
        chill.append(x['hourly'][0]['WindChillF'])
        hum.append(x['hourly'][0]['humidity'])
        cloud.append(x['hourly'][0]['cloudcover'])
        wind.append(x['hourly'][0]['WindGustMiles'])
        precip.append(x['hourly'][0]['precipInches'])
              
    except KeyError:
        print("Error")

# %%
for x in response9["data"]["weather"]:  
    
    try:
        date.append(x['date'])
        temp.append(x['maxtempF'])
        snow.append(x['totalSnow_cm'])
        feels.append(x['hourly'][0]['FeelsLikeF'])
        chill.append(x['hourly'][0]['WindChillF'])
        hum.append(x['hourly'][0]['humidity'])
        cloud.append(x['hourly'][0]['cloudcover'])
        wind.append(x['hourly'][0]['WindGustMiles'])
        precip.append(x['hourly'][0]['precipInches'])
              
    except KeyError:
        print("Error")

# %%
for x in response10["data"]["weather"]:  
    
    try:
        date.append(x['date'])
        temp.append(x['maxtempF'])
        snow.append(x['totalSnow_cm'])
        feels.append(x['hourly'][0]['FeelsLikeF'])
        chill.append(x['hourly'][0]['WindChillF'])
        hum.append(x['hourly'][0]['humidity'])
        cloud.append(x['hourly'][0]['cloudcover'])
        wind.append(x['hourly'][0]['WindGustMiles'])
        precip.append(x['hourly'][0]['precipInches'])
              
    except KeyError:
        print("Error")

# %%
for x in response11["data"]["weather"]:  
    
    try:
        date.append(x['date'])
        temp.append(x['maxtempF'])
        snow.append(x['totalSnow_cm'])
        feels.append(x['hourly'][0]['FeelsLikeF'])
        chill.append(x['hourly'][0]['WindChillF'])
        hum.append(x['hourly'][0]['humidity'])
        cloud.append(x['hourly'][0]['cloudcover'])
        wind.append(x['hourly'][0]['WindGustMiles'])
        precip.append(x['hourly'][0]['precipInches'])
              
    except KeyError:
        print("Error")

# %%
for x in response12["data"]["weather"]:  
    
    try:
        date.append(x['date'])
        temp.append(x['maxtempF'])
        snow.append(x['totalSnow_cm'])
        feels.append(x['hourly'][0]['FeelsLikeF'])
        chill.append(x['hourly'][0]['WindChillF'])
        hum.append(x['hourly'][0]['humidity'])
        cloud.append(x['hourly'][0]['cloudcover'])
        wind.append(x['hourly'][0]['WindGustMiles'])
        precip.append(x['hourly'][0]['precipInches'])
              
    except KeyError:
        print("Error")

# %%
for x in response13["data"]["weather"]:  
    
    try:
        date.append(x['date'])
        temp.append(x['maxtempF'])
        snow.append(x['totalSnow_cm'])
        feels.append(x['hourly'][0]['FeelsLikeF'])
        chill.append(x['hourly'][0]['WindChillF'])
        hum.append(x['hourly'][0]['humidity'])
        cloud.append(x['hourly'][0]['cloudcover'])
        wind.append(x['hourly'][0]['WindGustMiles'])
        precip.append(x['hourly'][0]['precipInches'])
              
    except KeyError:
        print("Error")

# %%
for x in response14["data"]["weather"]:  
    
    try:
        date.append(x['date'])
        temp.append(x['maxtempF'])
        snow.append(x['totalSnow_cm'])
        feels.append(x['hourly'][0]['FeelsLikeF'])
        chill.append(x['hourly'][0]['WindChillF'])
        hum.append(x['hourly'][0]['humidity'])
        cloud.append(x['hourly'][0]['cloudcover'])
        wind.append(x['hourly'][0]['WindGustMiles'])
        precip.append(x['hourly'][0]['precipInches'])
              
    except KeyError:
        print("Error")

# %%
for x in response15["data"]["weather"]:  
    
    try:
        date.append(x['date'])
        temp.append(x['maxtempF'])
        snow.append(x['totalSnow_cm'])
        feels.append(x['hourly'][0]['FeelsLikeF'])
        chill.append(x['hourly'][0]['WindChillF'])
        hum.append(x['hourly'][0]['humidity'])
        cloud.append(x['hourly'][0]['cloudcover'])
        wind.append(x['hourly'][0]['WindGustMiles'])
        precip.append(x['hourly'][0]['precipInches'])
              
    except KeyError:
        print("Error")

# %%
for x in response16["data"]["weather"]:  
    
    try:
        date.append(x['date'])
        temp.append(x['maxtempF'])
        snow.append(x['totalSnow_cm'])
        feels.append(x['hourly'][0]['FeelsLikeF'])
        chill.append(x['hourly'][0]['WindChillF'])
        hum.append(x['hourly'][0]['humidity'])
        cloud.append(x['hourly'][0]['cloudcover'])
        wind.append(x['hourly'][0]['WindGustMiles'])
        precip.append(x['hourly'][0]['precipInches'])
              
    except KeyError:
        print("Error")

# %%
for x in response17["data"]["weather"]:  
    
    try:
        date.append(x['date'])
        temp.append(x['maxtempF'])
        snow.append(x['totalSnow_cm'])
        feels.append(x['hourly'][0]['FeelsLikeF'])
        chill.append(x['hourly'][0]['WindChillF'])
        hum.append(x['hourly'][0]['humidity'])
        cloud.append(x['hourly'][0]['cloudcover'])
        wind.append(x['hourly'][0]['WindGustMiles'])
        precip.append(x['hourly'][0]['precipInches'])
              
    except KeyError:
        print("Error")

# %%
for x in response18["data"]["weather"]:  
    
    try:
        date.append(x['date'])
        temp.append(x['maxtempF'])
        snow.append(x['totalSnow_cm'])
        feels.append(x['hourly'][0]['FeelsLikeF'])
        chill.append(x['hourly'][0]['WindChillF'])
        hum.append(x['hourly'][0]['humidity'])
        cloud.append(x['hourly'][0]['cloudcover'])
        wind.append(x['hourly'][0]['WindGustMiles'])
        precip.append(x['hourly'][0]['precipInches'])
              
    except KeyError:
        print("Error")

# %%
for x in response19["data"]["weather"]:  
    
    try:
        date.append(x['date'])
        temp.append(x['maxtempF'])
        snow.append(x['totalSnow_cm'])
        feels.append(x['hourly'][0]['FeelsLikeF'])
        chill.append(x['hourly'][0]['WindChillF'])
        hum.append(x['hourly'][0]['humidity'])
        cloud.append(x['hourly'][0]['cloudcover'])
        wind.append(x['hourly'][0]['WindGustMiles'])
        precip.append(x['hourly'][0]['precipInches'])
              
    except KeyError:
        print("Error")

# %%
for x in response20["data"]["weather"]:  
    
    try:
        date.append(x['date'])
        temp.append(x['maxtempF'])
        snow.append(x['totalSnow_cm'])
        feels.append(x['hourly'][0]['FeelsLikeF'])
        chill.append(x['hourly'][0]['WindChillF'])
        hum.append(x['hourly'][0]['humidity'])
        cloud.append(x['hourly'][0]['cloudcover'])
        wind.append(x['hourly'][0]['WindGustMiles'])
        precip.append(x['hourly'][0]['precipInches'])
              
    except KeyError:
        print("Error")

# %%
for x in response21["data"]["weather"]:  
    
    try:
        date.append(x['date'])
        temp.append(x['maxtempF'])
        snow.append(x['totalSnow_cm'])
        feels.append(x['hourly'][0]['FeelsLikeF'])
        chill.append(x['hourly'][0]['WindChillF'])
        hum.append(x['hourly'][0]['humidity'])
        cloud.append(x['hourly'][0]['cloudcover'])
        wind.append(x['hourly'][0]['WindGustMiles'])
        precip.append(x['hourly'][0]['precipInches'])
              
    except KeyError:
        print("Error")

# %%
for x in response22["data"]["weather"]:  
    
    try:
        date.append(x['date'])
        temp.append(x['maxtempF'])
        snow.append(x['totalSnow_cm'])
        feels.append(x['hourly'][0]['FeelsLikeF'])
        chill.append(x['hourly'][0]['WindChillF'])
        hum.append(x['hourly'][0]['humidity'])
        cloud.append(x['hourly'][0]['cloudcover'])
        wind.append(x['hourly'][0]['WindGustMiles'])
        precip.append(x['hourly'][0]['precipInches'])
              
    except KeyError:
        print("Error")

# %%
for x in response23["data"]["weather"]:  
    
    try:
        date.append(x['date'])
        temp.append(x['maxtempF'])
        snow.append(x['totalSnow_cm'])
        feels.append(x['hourly'][0]['FeelsLikeF'])
        chill.append(x['hourly'][0]['WindChillF'])
        hum.append(x['hourly'][0]['humidity'])
        cloud.append(x['hourly'][0]['cloudcover'])
        wind.append(x['hourly'][0]['WindGustMiles'])
        precip.append(x['hourly'][0]['precipInches'])
              
    except KeyError:
        print("Error")

# %%
for x in response24["data"]["weather"]:  
    
    try:
        date.append(x['date'])
        temp.append(x['maxtempF'])
        snow.append(x['totalSnow_cm'])
        feels.append(x['hourly'][0]['FeelsLikeF'])
        chill.append(x['hourly'][0]['WindChillF'])
        hum.append(x['hourly'][0]['humidity'])
        cloud.append(x['hourly'][0]['cloudcover'])
        wind.append(x['hourly'][0]['WindGustMiles'])
        precip.append(x['hourly'][0]['precipInches'])
              
    except KeyError:
        print("Error")

# %%
for x in response25["data"]["weather"]:  
    
    try:
        date.append(x['date'])
        temp.append(x['maxtempF'])
        snow.append(x['totalSnow_cm'])
        feels.append(x['hourly'][0]['FeelsLikeF'])
        chill.append(x['hourly'][0]['WindChillF'])
        hum.append(x['hourly'][0]['humidity'])
        cloud.append(x['hourly'][0]['cloudcover'])
        wind.append(x['hourly'][0]['WindGustMiles'])
        precip.append(x['hourly'][0]['precipInches'])
              
    except KeyError:
        print("Error")

# %%
for x in response26["data"]["weather"]:  
    
    try:
        date.append(x['date'])
        temp.append(x['maxtempF'])
        snow.append(x['totalSnow_cm'])
        feels.append(x['hourly'][0]['FeelsLikeF'])
        chill.append(x['hourly'][0]['WindChillF'])
        hum.append(x['hourly'][0]['humidity'])
        cloud.append(x['hourly'][0]['cloudcover'])
        wind.append(x['hourly'][0]['WindGustMiles'])
        precip.append(x['hourly'][0]['precipInches'])
              
    except KeyError:
        print("Error")

# %%
for x in response27["data"]["weather"]:  
    
    try:
        date.append(x['date'])
        temp.append(x['maxtempF'])
        snow.append(x['totalSnow_cm'])
        feels.append(x['hourly'][0]['FeelsLikeF'])
        chill.append(x['hourly'][0]['WindChillF'])
        hum.append(x['hourly'][0]['humidity'])
        cloud.append(x['hourly'][0]['cloudcover'])
        wind.append(x['hourly'][0]['WindGustMiles'])
        precip.append(x['hourly'][0]['precipInches'])
              
    except KeyError:
        print("Error")

# %%
for x in response28["data"]["weather"]:  
    
    try:
        date.append(x['date'])
        temp.append(x['maxtempF'])
        snow.append(x['totalSnow_cm'])
        feels.append(x['hourly'][0]['FeelsLikeF'])
        chill.append(x['hourly'][0]['WindChillF'])
        hum.append(x['hourly'][0]['humidity'])
        cloud.append(x['hourly'][0]['cloudcover'])
        wind.append(x['hourly'][0]['WindGustMiles'])
        precip.append(x['hourly'][0]['precipInches'])
              
    except KeyError:
        print("Error")

# %%
for x in response29["data"]["weather"]:  
    
    try:
        date.append(x['date'])
        temp.append(x['maxtempF'])
        snow.append(x['totalSnow_cm'])
        feels.append(x['hourly'][0]['FeelsLikeF'])
        chill.append(x['hourly'][0]['WindChillF'])
        hum.append(x['hourly'][0]['humidity'])
        cloud.append(x['hourly'][0]['cloudcover'])
        wind.append(x['hourly'][0]['WindGustMiles'])
        precip.append(x['hourly'][0]['precipInches'])
              
    except KeyError:
        print("Error")

# %%
weather_dict = {
    "Date": date,
    "Temperature (F)": temp,
    "Feels Like (F)": feels,
    "Wind Chill (F)": chill,
    "Wind Gust (mph)": wind,
    "Humidity (%)": hum,
    "Cloud Cover (%)": cloud,
    "Rain Fall (in)": precip,
    "Snow Fall (cm)": snow}
cubs_weather_df = pd.DataFrame(weather_dict)
cubs_weather_df
# Out:
#            Date Temperature (F) Feels Like (F) Wind Chill (F) Wind Gust (mph)  \
# 0    2015-04-01              60             47             47              24
# 1    2015-04-02              54             47             47              26
# 2    2015-04-03              49             36             36              19
# 3    2015-04-04              51             35             35              20
# 4    2015-04-05              55             42             42              24
# ..          ...             ...            ...            ...             ...
# 912  2019-09-26              70             66             66              15
# 913  2019-09-27              74             69             69              21
# 914  2019-09-28              65             64             64              18
# 915  2019-09-29              67             62             62              17
# 916  2019-09-30              82             76             74              15
#
# ...

# %%
cubs_weather_df.dtypes
# Out:
# Date               object
# Temperature (F)    object
# Feels Like (F)     object
# Wind Chill (F)     object
# Wind Gust (mph)    object
# Humidity (%)       object
# Cloud Cover (%)    object
# Rain Fall (in)     object
# Snow Fall (cm)     object
# dtype: object

# %%
cubs_complete_df = cubs_df.merge(cubs_weather_df, how='left', on='Date')
cubs_complete_df
# Out:
#            Date      Month        Day  Season  Gm#   Tm  Opp Win/Loss  \
# 0    2015-04-05      April     Sunday    2015    1  CHC  STL        L
# 1    2015-04-08      April  Wednesday    2015    2  CHC  STL        W
# 2    2015-04-13      April     Monday    2015    6  CHC  CIN        W
# 3    2015-04-14      April    Tuesday    2015    7  CHC  CIN        L
# 4    2015-04-15      April  Wednesday    2015    8  CHC  CIN        W
# ..          ...        ...        ...     ...  ...  ...  ...      ...
# 400  2019-09-18  September  Wednesday    2019  152  CHC  CIN        L
# 401  2019-09-19  September   Thursday    2019  153  CHC  STL        L
# 402  2019-09-20  September     Friday    2019  154  CHC  STL        L
# 403  2019-09-21  September   Saturday    2019  155  CHC  STL        L
# 404  2019-09-22  September     Sunday    2019  156  CHC  STL        L
#
#      Season Wins  Season Losses  ... Day/ Night Game Attendance  \
# ...

# %%
cubs_complete_df.to_csv('Resources/cubs_complete.csv', index=False, encoding='utf-8')
print("Clean Up Complete")
# Out:
# Clean Up Complete
